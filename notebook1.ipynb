# %%
a=[1,2,3,4]
b=[10,20,30,40]
k=list(map(lambda a,b:a+b,a,b))
print(k)
# Out:
# [11, 22, 33, 44]

# %%
nums=[12,15,7,18,20,21,25]
k=list(filter(lambda x:(x%3==0 or x%5==0)and not(x%3==0 and x%5==0), nums))
print(k)
# Out:
# [12, 18, 20, 21, 25]

# %%
from functools import reduce
nums=[1,2,3,4]
k=reduce()
